# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('cdc_zika.csv')
# Out:
# C:\Users\Ryan\AppData\Local\Continuum\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#   report_date                location location_type  \
# 0  2016-03-19  Argentina-Buenos_Aires      province
# 1  2016-03-19  Argentina-Buenos_Aires      province
# 2  2016-03-19  Argentina-Buenos_Aires      province
# 3  2016-03-19  Argentina-Buenos_Aires      province
# 4  2016-03-19  Argentina-Buenos_Aires      province
# 5  2016-03-19  Argentina-Buenos_Aires      province
# 6  2016-03-19          Argentina-CABA      province
# 7  2016-03-19          Argentina-CABA      province
# 8  2016-03-19          Argentina-CABA      province
# 9  2016-03-19          Argentina-CABA      province
#
#                             data_field data_field_code  time_period  \
# 0     cumulative_confirmed_local_cases          AR0001          NaN
# 1      cumulative_probable_local_cases          AR0002          NaN
# 2  cumulative_confirmed_imported_cases          AR0003          NaN
# 3   cumulative_probable_imported_cases          AR0004          NaN
# ...

# %%
df['Country'] = df['location'].apply(lambda x: str(x).split('-')[0])
df['City'] = df['location'].apply(lambda x: str(x).split('-')[1] if '-' in str(x) else None)

# %%
del df['location']

# %%
df.head(15)
# Out:
#    report_date location_type                           data_field  \
# 0   2016-03-19      province     cumulative_confirmed_local_cases
# 1   2016-03-19      province      cumulative_probable_local_cases
# 2   2016-03-19      province  cumulative_confirmed_imported_cases
# 3   2016-03-19      province   cumulative_probable_imported_cases
# 4   2016-03-19      province         cumulative_cases_under_study
# 5   2016-03-19      province           cumulative_cases_discarded
# 6   2016-03-19      province     cumulative_confirmed_local_cases
# 7   2016-03-19      province      cumulative_probable_local_cases
# 8   2016-03-19      province  cumulative_confirmed_imported_cases
# 9   2016-03-19      province   cumulative_probable_imported_cases
# 10  2016-03-19      province         cumulative_cases_under_study
# 11  2016-03-19      province           cumulative_cases_discarded
# 12  2016-03-19      province     cumulative_confirmed_local_cases
# ...

# %%
by_c = df.groupby(df.City)

# %%
by_c.head()
# Out:
#        report_date location_type                           data_field  \
# 0       2016-03-19      province     cumulative_confirmed_local_cases
# 1       2016-03-19      province      cumulative_probable_local_cases
# 2       2016-03-19      province  cumulative_confirmed_imported_cases
# 3       2016-03-19      province   cumulative_probable_imported_cases
# 4       2016-03-19      province         cumulative_cases_under_study
# 6       2016-03-19      province     cumulative_confirmed_local_cases
# 7       2016-03-19      province      cumulative_probable_local_cases
# 8       2016-03-19      province  cumulative_confirmed_imported_cases
# 9       2016-03-19      province   cumulative_probable_imported_cases
# 10      2016-03-19      province         cumulative_cases_under_study
# 12      2016-03-19      province     cumulative_confirmed_local_cases
# 13      2016-03-19      province      cumulative_probable_local_cases
# ...

# %%
df.Country.value_counts()
# Out:
# Colombia                        86889
# Dominican_Republic               5716
# Brazil                           4253
# Mexico                           2880
# United_States                    2453
# Argentina                        2016
# El_Salvador                      1000
# Ecuador                           796
# United_States_Virgin_Islands      509
# Guatemala                         480
# Puerto_Rico                       260
# Panama                            148
# Nicaragua                         125
# Haiti                              52
# Norte                               7
# Sudeste                             7
# Sul                                 7
# Centro                              7
# nan                                 7
# Nordeste                            7
# Name: Country, dtype: int64

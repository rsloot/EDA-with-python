# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('tobacco.csv')

# %%
df.head(15)
# Out:
#     Year           State Smoke everyday Smoke some days Former smoker  \
# 0   1996     Puerto Rico          9.40%           5.10%           16%
# 1   1997     Puerto Rico          9.40%              5%        15.70%
# 2   1998     Puerto Rico         10.10%           5.20%        16.80%
# 3   1999     Puerto Rico          9.70%              4%        15.30%
# 4   2000     Puerto Rico          9.20%           3.90%        15.20%
# 5   2001     Puerto Rico             8%           4.50%           17%
# 6   2001  Virgin Islands          6.90%           2.70%        12.60%
# 7   2002     Puerto Rico          8.80%           4.40%        16.90%
# 8   2002  Virgin Islands             7%           2.40%        12.10%
# 9   2003     Puerto Rico          8.90%           4.60%        17.70%
# 10  2003  Virgin Islands          7.90%              2%        13.60%
# 11  2004     Puerto Rico          8.20%           4.40%        15.20%
# ...

# %%
ny = df.loc[df.State=='New York']

# %%
ny = ny.sort_values(by='Year').reset_index(drop=True)

# %%
def get_state(state):
    return df.loc[df.State==state].sort_values(by='Year').reset_index(drop=True)

# %%
az = get_state('Arizona')
ca = get_state('California')
ut = get_state('Utah')
wa = get_state('Washington')
wv = get_state('West Virginia')
ky = get_state('Kentucky')
tx = get_state('Texas')

# %%
tx
# Out:
#     Year  State Smoke everyday Smoke some days Former smoker Never smoked  \
# 0   1995  Texas         19.90%           3.60%        23.70%       52.80%
# 1   1996  Texas            17%           5.90%        21.20%       55.90%
# 2   1997  Texas         16.20%           6.30%        20.30%       57.10%
# 3   1998  Texas         15.60%           6.30%        22.60%       55.50%
# 4   1999  Texas            15%           7.50%        23.30%       54.30%
# 5   2000  Texas         15.40%           6.50%        21.90%       56.20%
# 6   2001  Texas         15.50%           6.90%        20.70%       56.90%
# 7   2002  Texas         16.60%           6.20%        20.90%       56.20%
# 8   2003  Texas         15.60%           6.50%        21.60%       56.30%
# 9   2004  Texas         13.60%           6.90%        20.20%       59.30%
# 10  2005  Texas         13.20%           6.80%           21%          59%
# 11  2006  Texas         12.60%           5.30%        21.70%       60.40%
# ...

# %%
wv
# Out:
#     Year          State Smoke everyday Smoke some days Former smoker  \
# 0   1995  West Virginia         23.70%           1.90%        23.30%
# 1   1996  West Virginia         23.90%           2.80%        22.90%
# 2   1997  West Virginia         24.50%           2.90%        24.30%
# 3   1998  West Virginia         24.90%           3.10%        23.80%
# 4   1999  West Virginia         23.80%           3.30%        23.80%
# 5   2000  West Virginia         23.10%              3%        25.30%
# 6   2001  West Virginia         23.50%           4.60%        24.70%
# 7   2002  West Virginia         23.80%           4.70%        24.20%
# 8   2003  West Virginia         22.60%           4.80%        25.80%
# 9   2004  West Virginia         21.80%           5.10%        25.10%
# 10  2005  West Virginia         21.30%           5.40%        24.30%
# 11  2006  West Virginia         21.30%           4.50%        24.70%
# 12  2007  West Virginia         21.70%           5.20%        24.50%
# ...

# %%
ky
# Out:
#     Year     State Smoke everyday Smoke some days Former smoker Never smoked  \
# 0   1995  Kentucky         24.90%           2.70%        22.30%       50.10%
# 1   1996  Kentucky         27.90%           3.80%        23.20%       45.20%
# 2   1997  Kentucky         27.60%           3.10%        23.50%       45.80%
# 3   1998  Kentucky            28%           2.80%        22.90%       46.30%
# 4   1999  Kentucky         25.60%           4.20%        23.20%       47.10%
# 5   2000  Kentucky         26.80%           3.70%           23%       46.50%
# 6   2001  Kentucky         26.20%           4.70%        23.60%       45.50%
# 7   2002  Kentucky         29.10%           3.50%           22%       45.50%
# 8   2003  Kentucky         26.80%              4%        22.50%       46.70%
# 9   2004  Kentucky            23%           4.50%        20.40%       52.10%
# 10  2005  Kentucky         23.50%           5.20%           24%       47.30%
# ...

# %%
df.dtypes
# Out:
# Year                int64
# State              object
# Smoke everyday     object
# Smoke some days    object
# Former smoker      object
# Never smoked       object
# Location 1         object
# dtype: object

# %%
df['Smoke everyday'] = np.array(list(map(lambda x: float(str(x)[:-1]), df['Smoke everyday'])))

# %%
df.head()
# Out:
#    Year        State  Smoke everyday Smoke some days Former smoker  \
# 0  1996  Puerto Rico             9.4           5.10%           16%
# 1  1997  Puerto Rico             9.4              5%        15.70%
# 2  1998  Puerto Rico            10.1           5.20%        16.80%
# 3  1999  Puerto Rico             9.7              4%        15.30%
# 4  2000  Puerto Rico             9.2           3.90%        15.20%
#
#   Never smoked     Location 1
# 0       69.50%  Puerto Rico\n
# 1       69.90%  Puerto Rico\n
# 2       67.90%  Puerto Rico\n
# 3          71%  Puerto Rico\n
# 4       71.60%  Puerto Rico\n

# %%
df.describe()
# Out:
#               Year  Smoke everyday
# count   876.000000      876.000000
# mean   2002.591324       16.555479
# std       4.593622        3.981661
# min    1995.000000        3.600000
# 25%    1999.000000       13.900000
# 50%    2003.000000       16.700000
# 75%    2007.000000       19.100000
# max    2010.000000       29.100000
